# %% [markdown]
# <a href="https://colab.research.google.com/github/Polarbeargo/Microsoft-Azure-Machine-Learning-Scholarship-Showcase-Project/blob/master/Cryptocurrency_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/price_prediction')
# !ls
# Out:
#  automl_dependencies.yml
# 'bitcoin_price_1week_Test - bitcoin_price_Aug2017_1week.csv.gsheet'
# 'bitcoin_price_Training - bitcoin_price.2013Apr-2017Aug.csv.csv.gsheet'
#  BTCUSDKRAKEN
#  multi_h5_model.h5
#  my_h5_model.h5

# %%
import numpy as np
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Bidirectional
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
import plotly.offline as py
import plotly.graph_objs as go
import seaborn as sns
import seaborn; seaborn.set()
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,6
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
data = pd.read_csv(filepath_or_buffer="BTCUSDKRAKEN", index_col="Date")

# %% [markdown]
# * Exploring data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1380 entries, 2014-01-07 to 2017-10-17
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Open               1380 non-null   float64
#  1   High               1380 non-null   float64
#  2   Low                1380 non-null   float64
#  3   Close              1380 non-null   float64
#  4   Volume (BTC)       1380 non-null   float64
#  5   Volume (Currency)  1380 non-null   float64
#  6   Weighted Price     1380 non-null   float64
# dtypes: float64(7)
# memory usage: 86.2+ KB

# %%
data.head()
# Out:
#                  Open       High  ...  Volume (Currency)  Weighted Price
# Date                              ...
# 2014-01-07  874.67040  892.06753  ...       13151.472844      841.835522
# 2014-01-08  810.00000  899.84281  ...       16097.329584      839.156269
# 2014-01-09  825.56345  870.00000  ...        6784.249982      831.572913
# 2014-01-10  839.99000  857.34056  ...        6780.220188      844.938794
# 2014-01-11  858.20000  918.05471  ...       16698.566929      890.671709
#
# [5 rows x 7 columns]

# %%
data.tail()
# Out:
#               Open    High  ...  Volume (Currency)  Weighted Price
# Date                        ...
# 2017-10-13  5429.8  5854.4  ...       5.178706e+07     5615.511555
# 2017-10-14  5626.7  5800.0  ...       1.719205e+07     5692.831135
# 2017-10-15  5800.0  5840.4  ...       2.545265e+07     5610.777658
# 2017-10-16  5673.2  5776.6  ...       1.778638e+07     5674.172630
# 2017-10-17  5738.7  5759.9  ...       1.869327e+07     5626.368279
#
# [5 rows x 7 columns]

# %%
data.isnull().any()
# Out:
# Open                 False
# High                 False
# Low                  False
# Close                False
# Volume (BTC)         False
# Volume (Currency)    False
# Weighted Price       False
# dtype: bool

# %%
# %matplotlib inline
import plotly
import plotly.graph_objects as go
fig = go.Figure(go.Scatter(x=data.index, y=data['Weighted Price'], name= 'Price'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6b7c4265-5cd9-4f86-ba14-ee69122d99c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b7c4265-5cd9-4f86-ba14-ee69122d99c2")) {
#                     Plotly.newPlot(
#                         '6b7c4265-5cd9-4f86-ba14-ee69122d99c2',
#                         [{"name": "Price", "type": "scatter", "x": ["2014-01-07", "2014-01-08", "2014-01-09", "2014-01-10", "2014-01-11", "2014-01-12", "2014-01-13", "2014-01-14", "2014-01-15", "2014-01-16", "2014-01-17", "2014-01-18", "2014-01-19", "2014-01-20", "2014-01-21", "2014-01-22", "2014-01-23", "2014-01-24", "2014-01-25", "2014-01-26", "2014-01-27", "2014-01-28", "2014-01-29", "2014-01-30", "2014-01-31", "2014-02-01", "2014-02-02", "2014-02-03", "2014-02-04", "2014-02-05", "2014-02-06", "2014-02-07", "2014-02-08", "2014-02-09", "2014-02-10", "2014-02-11", "2014-02-12", "2014-02-13", "2014-02-14", "2014-02-15", "2014-02-16", "2014-02-17", "2014-02-18", "2014-02-19", "2014-02-20", "2014-02-21", "2014-02-22", "2014-02-23", "2014-02-24", "2014-02-25", "2014-02-26", "2014-02-27", "2014-02-28", "2014-03-01", "2014-03-02", "2014-03-03", "2014-03-04", "2014-03-05", "2014-03-06", "2014-03-07", "2014-03-08", "2014-03-09", "2014-03-10", "2014-03-11", "2014-03-12", "2014-03-13", "2014-03-14", "2014-03-15", "2014-03-16", "2014-03-17", "2014-03-18", "2014-03-19", "2014-03-20", "2014-03-21", "2014-03-22", "2014-03-23", "2014-03-24", "2014-03-25", "2014-03-26", "2014-03-27", "2014-03-28", "2014-03-29", "2014-03-30", "2014-03-31", "2014-04-01", "2014-04-02", "2014-04-03", "2014-04-04", "2014-04-05", "2014-04-06", "2014-04-07", "2014-04-08", "2014-04-09", "2014-04-10", "2014-04-11", "2014-04-12", "2014-04-13", "2014-04-14", "2014-04-15", "2014-04-16", "2014-04-17", "2014-04-18", "2014-04-19", "2014-04-20", "2014-04-21", "2014-04-22", "2014-04-23", "2014-04-24", "2014-04-25", "2014-04-26", "2014-04-27", "2014-04-28", "2014-04-29", "2014-04-30", "2014-05-01", "2014-05-02", "2014-05-03", "2014-05-04", "2014-05-05", "2014-05-06", "2014-05-07", "2014-05-08", "2014-05-09", "2014-05-10", "2014-05-11", "2014-05-12", "2014-05-13", "2014-05-14", "2014-05-15", "2014-05-16", "2014-05-17", "2014-05-18", "2014-05-19", "2014-05-20", "2014-05-21", "2014-05-22", "2014-05-23", "2014-05-24", "2014-05-25", "2014-05-26", "2014-05-27", "2014-05-28", "2014-05-29", "2014-05-30", "2014-05-31", "2014-06-01", "2014-06-02", "2014-06-03", "2014-06-04", "2014-06-05", "2014-06-06", "2014-06-07", "2014-06-08", "2014-06-09", "2014-06-10", "2014-06-11", "2014-06-12", "2014-06-13", "2014-06-14", "2014-06-15", "2014-06-16", "2014-06-17", "2014-06-18", "2014-06-19", "2014-06-20", "2014-06-21", "2014-06-22", "2014-06-23", "2014-06-24", "2014-06-25", "2014-06-26", "2014-06-27", "2014-06-28", "2014-06-29", "2014-06-30", "2014-07-01", "2014-07-02", "2014-07-03", "2014-07-04", "2014-07-05", "2014-07-06", "2014-07-07", "2014-07-08", "2014-07-09", "2014-07-10", "2014-07-11", "2014-07-12", "2014-07-13", "2014-07-14", "2014-07-15", "2014-07-16", "2014-07-17", "2014-07-18", "2014-07-19", "2014-07-20", "2014-07-21", "2014-07-22", "2014-07-23", "2014-07-24", "2014-07-25", "2014-07-26", "2014-07-27", "2014-07-28", "2014-07-29", "2014-07-30", "2014-07-31", "2014-08-01", "2014-08-02", "2014-08-03", "2014-08-04", "2014-08-05", "2014-08-06", "2014-08-07", "2014-08-08", "2014-08-09", "2014-08-10", "2014-08-11", "2014-08-12", "2014-08-13", "2014-08-14", "2014-08-15", "2014-08-16", "2014-08-17", "2014-08-18", "2014-08-19", "2014-08-20", "2014-08-21", "2014-08-22", "2014-08-23", "2014-08-24", "2014-08-25", "2014-08-26", "2014-08-27", "2014-08-28", "2014-08-29", "2014-08-30", "2014-08-31", "2014-09-01", "2014-09-02", "2014-09-03", "2014-09-04", "2014-09-05", "2014-09-06", "2014-09-07", "2014-09-08", "2014-09-09", "2014-09-10", "2014-09-11", "2014-09-12", "2014-09-13", "2014-09-14", "2014-09-15", "2014-09-16", "2014-09-17", "2014-09-18", "2014-09-19", "2014-09-20", "2014-09-21", "2014-09-22", "2014-09-23", "2014-09-24", "2014-09-25", "2014-09-26", "2014-09-27", "2014-09-28", "2014-09-29", "2014-09-30", "2014-10-01", "2014-10-02", "2014-10-03", "2014-10-04", "2014-10-05", "2014-10-06", "2014-10-07", "2014-10-08", "2014-10-09", "2014-10-10", "2014-10-11", "2014-10-12", "2014-10-13", "2014-10-14" ...

# %%
sns.heatmap(data.corr(), annot=True, linewidths=0.1, vmin=0)

# %% [markdown]
# * Clean data

# %%
data['Weighted Price'].replace(0, np.nan, inplace=True)
data['Weighted Price'].fillna(method='ffill', inplace=True)

# %%
fig = go.Figure(go.Scatter(x=data.index, y=data['Weighted Price'], name= 'Price'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a33b0ad3-6c43-41b3-a67a-c738dcca0af9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a33b0ad3-6c43-41b3-a67a-c738dcca0af9")) {
#                     Plotly.newPlot(
#                         'a33b0ad3-6c43-41b3-a67a-c738dcca0af9',
#                         [{"name": "Price", "type": "scatter", "x": ["2014-01-07", "2014-01-08", "2014-01-09", "2014-01-10", "2014-01-11", "2014-01-12", "2014-01-13", "2014-01-14", "2014-01-15", "2014-01-16", "2014-01-17", "2014-01-18", "2014-01-19", "2014-01-20", "2014-01-21", "2014-01-22", "2014-01-23", "2014-01-24", "2014-01-25", "2014-01-26", "2014-01-27", "2014-01-28", "2014-01-29", "2014-01-30", "2014-01-31", "2014-02-01", "2014-02-02", "2014-02-03", "2014-02-04", "2014-02-05", "2014-02-06", "2014-02-07", "2014-02-08", "2014-02-09", "2014-02-10", "2014-02-11", "2014-02-12", "2014-02-13", "2014-02-14", "2014-02-15", "2014-02-16", "2014-02-17", "2014-02-18", "2014-02-19", "2014-02-20", "2014-02-21", "2014-02-22", "2014-02-23", "2014-02-24", "2014-02-25", "2014-02-26", "2014-02-27", "2014-02-28", "2014-03-01", "2014-03-02", "2014-03-03", "2014-03-04", "2014-03-05", "2014-03-06", "2014-03-07", "2014-03-08", "2014-03-09", "2014-03-10", "2014-03-11", "2014-03-12", "2014-03-13", "2014-03-14", "2014-03-15", "2014-03-16", "2014-03-17", "2014-03-18", "2014-03-19", "2014-03-20", "2014-03-21", "2014-03-22", "2014-03-23", "2014-03-24", "2014-03-25", "2014-03-26", "2014-03-27", "2014-03-28", "2014-03-29", "2014-03-30", "2014-03-31", "2014-04-01", "2014-04-02", "2014-04-03", "2014-04-04", "2014-04-05", "2014-04-06", "2014-04-07", "2014-04-08", "2014-04-09", "2014-04-10", "2014-04-11", "2014-04-12", "2014-04-13", "2014-04-14", "2014-04-15", "2014-04-16", "2014-04-17", "2014-04-18", "2014-04-19", "2014-04-20", "2014-04-21", "2014-04-22", "2014-04-23", "2014-04-24", "2014-04-25", "2014-04-26", "2014-04-27", "2014-04-28", "2014-04-29", "2014-04-30", "2014-05-01", "2014-05-02", "2014-05-03", "2014-05-04", "2014-05-05", "2014-05-06", "2014-05-07", "2014-05-08", "2014-05-09", "2014-05-10", "2014-05-11", "2014-05-12", "2014-05-13", "2014-05-14", "2014-05-15", "2014-05-16", "2014-05-17", "2014-05-18", "2014-05-19", "2014-05-20", "2014-05-21", "2014-05-22", "2014-05-23", "2014-05-24", "2014-05-25", "2014-05-26", "2014-05-27", "2014-05-28", "2014-05-29", "2014-05-30", "2014-05-31", "2014-06-01", "2014-06-02", "2014-06-03", "2014-06-04", "2014-06-05", "2014-06-06", "2014-06-07", "2014-06-08", "2014-06-09", "2014-06-10", "2014-06-11", "2014-06-12", "2014-06-13", "2014-06-14", "2014-06-15", "2014-06-16", "2014-06-17", "2014-06-18", "2014-06-19", "2014-06-20", "2014-06-21", "2014-06-22", "2014-06-23", "2014-06-24", "2014-06-25", "2014-06-26", "2014-06-27", "2014-06-28", "2014-06-29", "2014-06-30", "2014-07-01", "2014-07-02", "2014-07-03", "2014-07-04", "2014-07-05", "2014-07-06", "2014-07-07", "2014-07-08", "2014-07-09", "2014-07-10", "2014-07-11", "2014-07-12", "2014-07-13", "2014-07-14", "2014-07-15", "2014-07-16", "2014-07-17", "2014-07-18", "2014-07-19", "2014-07-20", "2014-07-21", "2014-07-22", "2014-07-23", "2014-07-24", "2014-07-25", "2014-07-26", "2014-07-27", "2014-07-28", "2014-07-29", "2014-07-30", "2014-07-31", "2014-08-01", "2014-08-02", "2014-08-03", "2014-08-04", "2014-08-05", "2014-08-06", "2014-08-07", "2014-08-08", "2014-08-09", "2014-08-10", "2014-08-11", "2014-08-12", "2014-08-13", "2014-08-14", "2014-08-15", "2014-08-16", "2014-08-17", "2014-08-18", "2014-08-19", "2014-08-20", "2014-08-21", "2014-08-22", "2014-08-23", "2014-08-24", "2014-08-25", "2014-08-26", "2014-08-27", "2014-08-28", "2014-08-29", "2014-08-30", "2014-08-31", "2014-09-01", "2014-09-02", "2014-09-03", "2014-09-04", "2014-09-05", "2014-09-06", "2014-09-07", "2014-09-08", "2014-09-09", "2014-09-10", "2014-09-11", "2014-09-12", "2014-09-13", "2014-09-14", "2014-09-15", "2014-09-16", "2014-09-17", "2014-09-18", "2014-09-19", "2014-09-20", "2014-09-21", "2014-09-22", "2014-09-23", "2014-09-24", "2014-09-25", "2014-09-26", "2014-09-27", "2014-09-28", "2014-09-29", "2014-09-30", "2014-10-01", "2014-10-02", "2014-10-03", "2014-10-04", "2014-10-05", "2014-10-06", "2014-10-07", "2014-10-08", "2014-10-09", "2014-10-10", "2014-10-11", "2014-10-12", "2014-10-13", "2014-10-14" ...

# %% [markdown]
# * Scaling data using MinMax normalize to fit feature Weighted Price  then transforming it so that the values fit within a range or scale between 0–1.[MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
from sklearn.preprocessing import MinMaxScaler
values = data['Weighted Price'].values.reshape(-1,1).astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %% [markdown]
# * Spilt data

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
print(len(train), len(test))
# Out:
# 965 415

# %%
def to_numpy_array(df, look_back=1):
    X, Y = [], []
    for i in range(len(df) - look_back):
        a = df[i:(i + look_back), 0]
        X.append(a)
        Y.append(df[i + look_back, 0])
    print(len(Y))
    return np.array(X), np.array(Y)

# %%
# Reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = to_numpy_array(train, look_back)
testX, testY = to_numpy_array(test, look_back)
# Out:
# 964
# 414

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# * Running Bidirectional LSTM with 300 epoches Modified `shuffle=True` which only shuffle training dataset produce better result in train vs validate loss plot. Detail reference: [For Keras fit method, does “shuffle=True” shuffle BOTH the training and validation samples or just the training dataset?](https://forums.fast.ai/t/for-keras-fit-method-does-shuffle-true-shuffle-both-the-training-and-validation-samples-or-just-the-training-dataset/2992)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]))))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=True)
model.save("my_h5_model.h5")
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 200)               81600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 81,801
# Trainable params: 81,801
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
predict = model.predict(testX)
plt.plot(predict, label='predict')
plt.plot(testY, label='true')
plt.legend()
plt.show()

# %%
predict_inverse = scaler.inverse_transform(predict.reshape(-1, 1))
testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))

# %% [markdown]
# * RMSE

# %%
rmse = sqrt(mean_squared_error(testY_inverse, predict_inverse))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 121.859

# %%
plt.plot(predict_inverse, label='predict')
plt.plot(testY_inverse, label='actual', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# * Convert X to dates

# %%
predictDates = data.tail(len(testX)).index

# %%
testY_reshape = testY_inverse.reshape(len(testY_inverse))
predict_reshape = predict_inverse.reshape(len(predict_inverse))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=predictDates, y=testY_reshape, name= 'Actual Price'))
fig.add_trace(go.Scatter(x=predictDates, y=predict_reshape, name= 'Predict Price'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="541c8030-9ea9-41fe-9d7c-4ce7155848bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("541c8030-9ea9-41fe-9d7c-4ce7155848bb")) {
#                     Plotly.newPlot(
#                         '541c8030-9ea9-41fe-9d7c-4ce7155848bb',
#                         [{"name": "Actual Price", "type": "scatter", "x": ["2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017 ...

# %% [markdown]
# * Train with addditional feature

# %% [markdown]
# Modified `cols, names = list(), list()` to `cols, names = [], []` base on [[] and {} vs list() and dict(), which is better?](https://stackoverflow.com/questions/5790860/and-vs-list-and-dict-which-is-better)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = [], []
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
values = data[['Weighted Price'] + ['Volume (BTC)'] + ['Volume (Currency)']].values.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
reframed = series_to_supervised(scaled, 1, 1)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)
# 1   0.116909   0.000715   0.000177  0.116422  0.000878  0.000216
# 2   0.116422   0.000878   0.000216  0.115041  0.000373  0.000091
# 3   0.115041   0.000373   0.000091  0.117474  0.000367  0.000091
# 4   0.117474   0.000367   0.000091  0.125800  0.000858  0.000225
# 5   0.125800   0.000858   0.000225  0.120299  0.001164  0.000294

# %%
reframed.drop(reframed.columns[[4,5]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)
# 1   0.116909   0.000715   0.000177  0.116422
# 2   0.116422   0.000878   0.000216  0.115041
# 3   0.115041   0.000373   0.000091  0.117474
# 4   0.117474   0.000367   0.000091  0.125800
# 5   0.125800   0.000858   0.000225  0.120299

# %%
values = reframed.values
n_train_hours = int(len(values) * 0.7)
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (965, 1, 3) (965,) (414, 1, 3) (414,)

# %%
multi_model = Sequential()
multi_model.add(Bidirectional(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2]))))
multi_model.add(Dense(1))
multi_model.compile(loss='mae', optimizer='adam')

multi_history = multi_model.fit(train_X, train_y, epochs=300, batch_size=100, validation_data=(test_X, test_y), verbose=0, shuffle=True)
model.save("multi_h5_model.h5")
print(multi_model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_5 (Bidirection (None, 200)               83200
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 83,401
# Trainable params: 83,401
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.plot(multi_history.history['loss'], label='multi_features_train')
plt.plot(multi_history.history['val_loss'], label='multi_features_test')
plt.legend()
plt.show()

# %%
predict = multi_model.predict(test_X)
plt.plot(predict, label='predict')
plt.plot(test_y, label='true')
plt.legend()
plt.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_predict = concatenate((predict, test_X[:, 1:]), axis=1)
inv_predict = scaler.inverse_transform(inv_predict)
inv_predict = inv_predict[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_predict))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 100.127

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=predictDates, y=inv_y, name= 'Actual Price'))
fig.add_trace(go.Scatter(x=predictDates, y=inv_predict, name= 'Multi Features Predict Price'))
fig.add_trace(go.Scatter(x=predictDates, y=predict_reshape, name= 'Predict Price'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ffa87a3c-fe75-432d-9a8a-5dc1c90d406e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ffa87a3c-fe75-432d-9a8a-5dc1c90d406e")) {
#                     Plotly.newPlot(
#                         'ffa87a3c-fe75-432d-9a8a-5dc1c90d406e',
#                         [{"name": "Actual Price", "type": "scatter", "x": ["2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017 ...

# %% [markdown]
# - Bidirectional LSTM with single feature of `Weighted Price` have RMSE of 94.266
# - Bidirectional LSTM with features of `Volume(BTC)`, `Volume(Currency)` and `Weighted Price` have RMSE of 96.184
# - Bidirectional LSTM with multi features shows more accurate results

# %% [markdown]
# * Install Azure Machine Learning SDK

# %%
pip install --upgrade azureml-sdk
# Out:
# Collecting azureml-sdk
#   Downloading https://files.pythonhosted.org/packages/ee/90/6cc989f24226f37f9498bc472bef7690228fe42efed7b6d2b7fa0f58dcca/azureml_sdk-1.13.0-py3-none-any.whl
# Collecting azureml-pipeline~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/79/66/c3d5f0a727553024549a18a7ecb8421ae40fe97bcedc0b5ddab51fdf81a7/azureml_pipeline-1.13.0-py3-none-any.whl
# Collecting azureml-dataset-runtime[fuse]~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/c6/d4/5c69dae15da96d0cd2fa318ed57c3fbe9faae5362c05e68c0380cc506023/azureml_dataset_runtime-1.13.0-py3-none-any.whl
# Collecting azureml-train~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bf/79/bfeb0fefbc09eddc9286d3e2d6a6db8f5702f24467f6bf3d6e601128355e/azureml_train-1.13.0-py3-none-any.whl
# Collecting azureml-core~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/69/79/5044b68945ddb93bb43fcb21b0d48b2cca7b7e57ef122a384187ffdb855f/azureml_core-1.13.0.post1-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 5.4MB/s
# Collecting azureml-train-automl-client~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/3d/54f6f2e86d1850f15fc3e1e673be754aa25a1e60d5537ed193b14b501a3a/azureml_train_automl_client-1.13.0.post2-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 14.5MB/s
# Collecting azureml-pipeline-core~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/07/8a/46989605974fca9dba0191b84927ebdb9dbe019834dce664dcc0138b8a88/azureml_pipeline_core-1.13.0-py3-none-any.whl (300kB)
#      |████████████████████████████████| 307kB 42.4MB/s
# Collecting azureml-pipeline-steps~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/76/f0/cd90b6b2c5468728ef3d93bd0fbfc99d9074a8f8df31e42b7f9db1c43b4c/azureml_pipeline_steps-1.13.0-py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 10.6MB/s
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading https://files.pythonhosted.org/packages/f3/99/0a605f016121ca314d1469dc9069e4978395bc46fda40f73099d90ad3ba4/pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 201kB/s
# Collecting azureml-dataprep<2.1.0a,>=2.0.1a
#   Downloading https://files.pythonhosted.org/packages/c4/c9/0387c8a868bd91c5f3e4c8d8559df008d3245d032ffe0403a73dbf1e00dc/azureml_dataprep-2.0.10-py3-none-any.whl (28.2MB)
#      |████████████████████████████████| 28.2MB 186kB/s
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading https://files.pythonhosted.org/packages/04/0b/4506cb2e831cea4b0214d3625430e921faaa05a7fb520458c75a2dbd2152/fusepy-3.0.1.tar.gz
# Collecting azureml-train-core~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/46/2e/584f468efa8999f2bcf8ccc87f0f6b96960d13e54dd7d8f555a5fc345b1c/azureml_train_core-1.13.0-py3-none-any.whl (8.6MB)
#      |████████████████████████████████| 8.6MB 50.2MB/s
# Collecting msrest>=0.5.1
#   Downloading https://files.pythonhosted.org/packages/fa/f5/9e315fe8cb985b0ce052b34bcb767883dc739f46fadb62f05a7e6d6eedbe/msrest-0.6.19-py2.py3-none-any.whl (84kB)
#      |████████████████████████████████| 92kB 13.8MB/s
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading https://files.pythonhosted.org/packages/51/76/1cacd32812c88fc79435a90a64f37cbc92fb95516c91c0e856c2e88ac8f3/azure_mgmt_storage-16.0.0-py2.py3-none-any.whl (811kB)
#      |████████████████████████████████| 819kB 57.4MB/s
# Requirement already satisfied, skipping upgrade: jmespath in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.13.0->azureml-sdk) (0.10.0)
# Requirement already satisfied, skipping upgrade: contextlib2 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.13.0->azureml-sdk) (0.5.5)
# Collecting SecretStorage
#   Downloading https://files.pythonhosted.org/packages/c3/50/8a02cad020e949e6d7105f5f4530d41e3febcaa5b73f8f2148aacb3aeba5/SecretStorage-3.1.2-py3-none-any.whl
# Collecting msrestazure>=0.4.33
#   Downloading https://files.pythonhosted.org/packages/5e/3a/7adb08fd2f0ee6fdfd03685fac38477b64f184943dcf6ea0cbffb205f22d/msrestazure-0.6.4-py2.py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 7.5MB/s
# Collecting PyJWT
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.13.0->azureml-sdk) (2.23.0)
# Collecting backports.tempfile
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting docker
#   Downloading https://files.pythonhosted.org/packages/9e/8c/8d42dbd83679483db207535f4fb02dc84325fa78b290f057694b057fcd21/docker-4.3.1-py2.py3-none-any.whl (145kB)
#      |████████████████████████████████| 153kB 62.0MB/s
# Collecting ndg-httpsclient
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting pyopenssl
#   Downloading https://files.pythonhosted.org/packages/9e/de/f8342b68fa9e981d348039954657bdf681b2ab93de27443be51865ffa310/pyOpenSSL-19.1.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 11.0MB/s
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.13.0->azureml-sdk) (2.8.1)
# Collecting adal>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/46/58/a19e0eb0c388fb7aced40f940c09069343862613d83095b592a8d3961ba1/adal-1.2.4-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 11.0MB/s
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.13.0->azureml-sdk) (1.24.3)
# Collecting azure-mgmt-resource<=10.2.0,>=1.2.1
#   Downloading https://files.pythonhosted.org/packages/af/b3/8009c149d7d162b7a2a22a5007f984aa090f089bf8dc09e7e84bd354b868/azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968kB)
#      |████████████████████████████████| 972kB 48.8MB/s
# Collecting pathspec
#   Downloading https://files.pythonhosted.org/packages/5d/d0/887c58853bd4b6ffc7aa9cdba4fc57d7b979b45888a6bd47e4568e1cf868/pathspec-0.8.0-py2.py3-none-any.whl
# Collecting azure-common>=1.1.12
#   Downloading https://files.pythonhosted.org/packages/e5/4d/d000fc3c5af601d00d55750b71da5c231fcb128f42ac95b208ed1091c2c1/azure_common-1.1.25-py2.py3-none-any.whl
# Collecting ruamel.yaml>=0.15.35
#   Downloading https://files.pythonhosted.org/packages/7e/39/186f14f3836ac5d2a6a042c8de69988770e8b9abb537610edc429e4914aa/ruamel.yaml-0.16.12-py2.py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 57.7MB/s
# Collecting jsonpickle
#   Downloading https://files.pythonhosted.org/packages/af/ca/4fee219cc4113a5635e348ad951cf8a2e47fed2e3342312493f5b73d0007/jsonpickle-1.4.1-py2.py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/b4/50/7a923f58bf053280fe1890f3332c08f6a82a208c92035ad8f7888c87b786/azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94kB)
#      |████████████████████████████████| 102kB 14.3MB/s
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/c9/fd/40de0dbc7542fe2492fa9a6d73e720ee7558e2857156b81f70249047f046/azure_mgmt_keyvault-7.0.0-py2.py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 57.4MB/s
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading https://files.pythonhosted.org/packages/c0/9c/647e559a6e8be493dc2a7a5d15d26cb501ca60ec299b356f23839a673a83/cryptography-3.1-cp35-abi3-manylinux2010_x86_64.whl (2.6MB)
#      |████████████████████████████████| 2.6MB 52.1MB/s
# Requirement already satisfied, skipping upgrade: pytz in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.13.0->azureml-sdk) (2018.9)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/97/70/8c2d0509db466678eba16fa2b0a539499f3b351b1f2993126ad843d5be13/azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718kB)
#      |████████████████████████████████| 727kB 48.1MB/s
# Collecting azure-graphrbac>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/3e/93/02056aca45162f9fc275d1eaad12a2a07ef92375afb48eabddc4134b8315/azure_graphrbac-0.61.1-py2.py3-none-any.whl (141kB)
#      |████████████████████████████████| 143kB 64.3MB/s
# Collecting azureml-automl-core~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/63/81/b6f6f67b8f356bf9485589191c2770213108dc9cb47065fb880593c137c7/azureml_automl_core-1.13.0-py3-none-any.whl (169kB)
#      |████████████████████████████████| 174kB 64.5MB/s
# Collecting azureml-telemetry~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/b9/a7/e1f5385e5777e241b92ae2a550ab76881e1b24e15250a88e9ce357bdefbe/azureml_telemetry-1.13.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from pyarrow<2.0.0,>=0.17.0->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk) (1.18.5)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/7a/9372cd51fc3408ede0fab950ef9a6518cad34ef36e199982bb1ddfa18512/azure_identity-1.2.0-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 11.1MB/s
# Collecting azureml-dataprep-native<21.0.0,>=20.1.1
#   Downloading https://files.pythonhosted.org/packages/27/72/4b241c355abd12d2fafb7d0584da229cb081a2c53b5ec5f2f348308e2265/azureml_dataprep_native-20.1.1-cp36-cp36m-manylinux1_x86_64.whl (11.1MB)
#      |████████████████████████████████| 11.1MB 57.5MB/s
# Requirement already satisfied, skipping upgrade: cloudpickle<2.0.0,>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk) (1.3.0)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading https://files.pythonhosted.org/packages/f0/a3/c326bf11c676d305e6a13cf87c04c6a500d3de6e468173f678fba373020f/dotnetcore2-2.1.16-py3-none-manylinux1_x86_64.whl (28.7MB)
#      |████████████████████████████████| 28.7MB 87kB/s
# Collecting azureml-train-restclients-hyperdrive~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/1b/e7/40bff5e1e60eb79e98981b3799cb61b95ae3e4e5547aa53f0969cc40013e/azureml_train_restclients_hyperdrive-1.13.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk) (1.3.0)
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.2MB/s
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk) (2020.6.20)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/4f/da/545b3d2496ac08fb4b4c2d784c8d92cb9bfc843801a53dc870bfafe81f0d/azure_mgmt_core-1.2.0-py2.py3-none-any.whl
# Collecting jeepney>=0.4.2
#   Downloading https://files.pythonhosted.org/packages/79/31/2e8d42727595faf224c6dbb748c32b192e212f25495fe841fb7ce8e168b8/jeepney-0.4.3-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from msrestazure>=0.4.33->azureml-core~=1.13.0->azureml-sdk) (1.15.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->azureml-core~=1.13.0->azureml-sdk) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->azureml-core~=1.13.0->azureml-sdk) (3.0.4)
# Collecting backports.weakref
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting websocket-client>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 54.8MB/s
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from ndg-httpsclient->azureml-core~=1.13.0->azureml-sdk) (0.4.8)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading https://files.pythonhosted.org/packages/88/ff/ec25dc01ef04232a9e68ff18492e37dfa01f1f58172e702ad4f38536d41b/ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549kB)
#      |████████████████████████████████| 552kB 43.8MB/s
# Requirement already satisfied, skipping upgrade: importlib-metadata in /usr/local/lib/python3.6/dist-packages (from jsonpickle->azureml-core~=1.13.0->azureml-sdk) (1.7.0)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.13.0->azureml-sdk) (1.14.2)
# Collecting applicationinsights
#   Downloading https://files.pythonhosted.org/packages/a1/53/234c53004f71f0717d8acd37876e0b65c121181167057b9ce1b1795f96a0/applicationinsights-0.11.9-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 8.3MB/s
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/9c/8c/6463dc620629d71c02f3f1a7dc30aab8e4f1a08ef64726cc3dd4f7949096/azure_core-1.8.1-py2.py3-none-any.whl (121kB)
#      |████████████████████████████████| 122kB 52.7MB/s
# Collecting msal-extensions~=0.1.3
#   Downloading https://files.pythonhosted.org/packages/21/9b/8bc67822e98573fe0460e30ad0202ab9e0638a42878041c65a6fe857babe/msal_extensions-0.1.3-py2.py3-none-any.whl
# Collecting msal<2.0.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fe/a9/4644452f6b055662854b826daa9971b6158bffbf11416e67e738f0ee4d93/msal-1.5.0-py2.py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Collecting distro>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/25/b7/b3c4270a11414cb22c6352ebc7a83aaa3712043be29daa05018fd5a5c956/distro-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata->jsonpickle->azureml-core~=1.13.0->azureml-sdk) (3.1.0)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.13.0->azureml-sdk) (2.20)
# Collecting portalocker~=1.0
#   Downloading https://files.pythonhosted.org/packages/3b/e7/ceef002a300a98a208232fab593183249b6964b306ee7dabb29908419cca/portalocker-1.7.1-py2.py3-none-any.whl
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py) ... done
#   Created wheel for fusepy: filename=fusepy-3.0.1-cp36-none-any.whl size=10504 sha256=4b2092d07292720f64880b8646cd56188fa32e23da5f8c6d5352d798c7b58a0d
#   Stored in directory: /root/.cache/pip/wheels/4c/a5/91/7772af9e21c461f07bb40f26d928d7d231d224977dd8353bab
# Successfully built fusepy
# Installing collected packages: isodate, msrest, azure-common, azure-core, azure-mgmt-core, azure-mgmt-storage, jeepney, cryptography, SecretStorage, PyJWT, adal, msrestazure, backports.weakref, backports.tempfile, websocket-client, docker, pyopenssl, ndg-httpsclient, azure-mgmt-resource, pathspec, ruamel.yaml.clib, ruamel.yaml, jsonpickle, azure-mgmt-authorization, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-graphrbac, azureml-core, azureml-pipeline-core, pyarrow, portalocker, msal, msal-extensions, azure-identity, azureml-dataprep-native, distro, dotnetcore2, azureml-dataprep, fusepy, azureml-dataset-runtime, applicationinsights, azureml-telemetry, azureml-automl-core, azureml-train-automl-client, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-pipeline-steps, azureml-pipeline, azureml-train, azureml-sdk
#   Found existing installation: pyarrow 0.14.1
#     Uninstalling pyarrow-0.14.1:
#       Successfully uninstalled pyarrow-0.14.1
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.1 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-core-1.2.0 azure-mgmt-keyvault-7.0.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-16.0.0 azureml-automl-core-1.13.0 azureml-core-1.13.0.post1 azureml-dataprep-2.0.10 azureml-dataprep-native-20.1.1 azureml-dataset-runtime-1.13.0 azureml-pipeline-1.13.0 azureml-pipeline-core-1.13.0 azureml-pipeline-steps-1.13.0 azureml-sdk-1.13.0 azureml-telemetry-1.13.0 azureml-train-1.13.0 azureml-train-automl-client-1.13.0.post2 azureml-train-core-1.13.0 azureml-train-restclients-hyperdrive-1.13.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cryptography-3.1 distro-1.5.0 docker-4.3.1 dotnetcore2-2.1.16 fusepy-3.0.1 isodate-0.6.0 jeepney-0.4.3 jsonpickle-1.4.1 msal-1.5.0 msal-extensions-0.1.3 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 pathspec-0.8.0 portalocker-1.7.1 pyarrow-1.0.1 pyopenssl-19.1.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 websocket-client-0.57.0

# %%
import azureml.core
from azureml.core import Workspace
from azureml.core.webservice import Webservice, AksWebservice
from azureml.core.image import Image
from azureml.core.model import Model

print("Azure ML SDK version:", azureml.core.VERSION)
# Out:
# Azure ML SDK version: 1.13.0

# %%
from azureml.core.workspace import Workspace
from azureml.core.experiment import Experiment
from azureml.train.automl import AutoMLConfig
import logging

# %%
#Provide the Subscription ID of your existing Azure subscription
subscription_id = "" # <- needs to be the subscription within the Azure resource group for this lesson

#Provide values for the existing Resource Group 
resource_group = "" # <- enter the name of your Azure Resource Group

#Provide the Workspace Name and Azure Region of the Azure Machine Learning Workspace
workspace_name = "" # <- enter the name of the Azure Machine Learning workspace
workspace_region = "eastus" # <- region of your Azure Machine Learning workspace

# %%
ws = Workspace.create(
    name = workspace_name,
    subscription_id = subscription_id,
    resource_group = resource_group, 
    location = workspace_region,
    exist_ok = True)

ws.write_config()

print('Workspace configuration succeeded')

# %%
# Display a summary of the current environment
import pandas as pd
output = {}
output['SDK version'] = azureml.core.VERSION
output['Workspace'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(data=output, index=['']).T

# %%
# register the model for deployment
model = Model.register(model_path = model_path, # this points to a local file
                       model_name = "Cryptocurrency-Price-predictor", # name the model is registered as
                       tags = {'area': "auto", 'type': "regression"}, 
                       description = "Cryptocurrency Price Predictor", 
                       workspace = ws)

print()
print("Model registered: {} \nModel Description: {} \nModel Version: {}".format(model.name, 
                                                                                model.description, model.version))

# %% [markdown]
# ## Deploy the Model as a Web Service

# %%
# %%writefile scoring_service.py

import json
import numpy as np
import pandas as pd
import azureml.core
import azureml.train.automl
from azureml.core.model import Model
import joblib

columns = ['']

def init():
    # One-time initialization of predictive model and scaler
    global model
    
    print("Azure ML SDK version:", azureml.core.VERSION)
    model_name = 'Cryptocurrency-Price-predictor'
    print('Looking for model path for model: ', model_name)
    model_path = Model.get_model_path(model_name=model_name)
    print('Looking for model in: ', model_path)
    model = joblib.load(model_path)
    print('Model loaded...')

def run(input_json):     
    try:
        inputs = json.loads(input_json)
        data_df = pd.DataFrame(np.array(inputs).reshape(-1, len(columns)), columns = columns)
        # Get the predictions...
        prediction = model.predict(data_df)
        prediction = json.dumps(prediction.tolist())
    except Exception as e:
        prediction = str(e)
    return prediction

# %%
from azureml.core import Environment
myEnv = Environment.from_conda_specification('myenv', './automl_dependencies.yml')
myEnv.register(workspace=ws)

# %%
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AciWebservice

inference_config = InferenceConfig(entry_script='scoring_service.py', environment=myEnv)
aci_config = AciWebservice.deploy_configuration(
    cpu_cores = 1, 
    memory_gb = 1, 
    tags = {'name': 'aci-cluster'}, 
    description = 'Cryptocurrency Price Prediction Web Service')

# %% [markdown]
# Now you are ready to begin your deployment to the Azure Container Instance.
#
# Run the following cell:  you may be waiting **20-25 minutes** for completion, while the _Running_ tag adds progress dots.
#
# You will see output similar to the following when your web service is ready:
#
# `
# Succeeded
# ACI service creation operation finished, operation "Succeeded"`

# %%
from azureml.core import Webservice
from azureml.exceptions import WebserviceException

service_name = 'cryptocurrency-price-prediction'

# Remove any existing service under the same name.
try:
    Webservice(ws, service_name).delete()
except WebserviceException:
    pass

webservice = Model.deploy(workspace=ws,
                       name=service_name,
                       models=[model],
                       inference_config=inference_config,
                       deployment_config=aci_config)
webservice.wait_for_deployment(show_output=True)

# %% [markdown]
# ## Test the deployed web service

# %% [markdown]
# ### Make direct calls on the service object

# %%
import json

data1 = [1, 2, 5, 9, 4, 27, 5, 'Memorial Day', True, 0, 0.0, 0.0, 65]

data2 = [[1, 3, 10, 15, 4, 27, 7, 'None', False, 0, 2.0, 1.0, 80], 
         [1, 2, 5, 9, 4, 27, 5, 'Memorial Day', True, 0, 0.0, 0.0, 65]]

result = webservice.run(json.dumps(data1))
print('Predictions for data1')
print(result)

result = webservice.run(json.dumps(data2))
print('Predictions for data2')
print(result)

# %% [markdown]
# ### Consume the Deployed Web Service
#
# Execute the code below to consume the deployed webservice over HTTP.

# %%
import requests

url = webservice.scoring_uri
print('ACI Service: {} scoring URI is: {}'.format(service_name, url))
headers = {'Content-Type':'application/json'}

response = requests.post(url, json.dumps(data1), headers=headers)
print('Predictions for data1')
print(response.text)
response = requests.post(url, json.dumps(data2), headers=headers)
print('Predictions for data2')
print(response.text)
